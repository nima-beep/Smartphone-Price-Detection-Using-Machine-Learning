# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score


# read data 
data = pd.read_csv('Dataset/final_dataset.csv')

data
# Out:
#      PriceRange  ReleaseYear  Camera  AvailableColors  Ram_GB  NetworkSupport  \
# 0           4.0       2022.0    32.0              4.0     8.0             4.0
# 1           1.0       2021.0     5.0              2.0     4.0             3.0
# 2           3.0       2021.0    32.0              4.0     8.0             4.0
# 3           1.0       2021.0    13.0              2.0     6.0             3.0
# 4           4.0       2021.0     4.0              3.0    12.0             4.0
# ..          ...          ...     ...              ...     ...             ...
# 489         1.0       2018.0     8.0              3.0     3.0             3.0
# 490         2.0       2017.0    13.0              4.0     6.0             3.0
# 491         0.0       2017.0     8.0              4.0     2.0             3.0
# 492         0.0       2017.0     5.0              3.0     1.0             3.0
# 493         0.0       2018.0     2.0              2.0     1.0             3.0
#
#      BluetoothVersion  Rom_GB  BatteryCapacity  VideoRes  ...  USB_Version  \
# 0                 5.0   128.0           4500.0    2160.0  ...          3.2
# 1                 5.0    64.0           5000.0       0.0  ...          2.0
# 2                 5.0   128.0           4500.0    2160.0  ...          2.0
# 3                 5.0   128.0           6000.0    1080.0  ...          2.0
# 4                 5.2   256.0           4400.0    2160.0  ...          3.2
# ..                ...     ...              ...       ...  ...          ...
# 489               4.2    16.0           2990.0     720.0  ...          2.0
# 490               5.0    64.0           3090.0    2160.0  ...          3.1
# 491               4.0    16.0           2630.0     720.0  ...          2.0
# 492               4.1     8.0           4100.0     720.0  ...          2.0
# 493               4.2     8.0           2150.0       0.0  ...          2.0
#
#      TypeC  NFC                                 Display  Protection  \
# 0        1    1           Dynamic AMOLED 2X Touchscreen           1
# 1        1    0                     PLS IPS Touchscreen           0
# 2        1    0                Super AMOLED Touchscreen           1
# 3        1    0                Super AMOLED Touchscreen           0
# 4        1    1  Foldable Dynamic AMOLED 2X Touchscreen           1
# ..     ...  ...                                     ...         ...
# 489      0    0                     IPS LCD Touchscreen           1
# 490      1    1                     IPS LCD Touchscreen           1
# 491      0    0                     IPS LCD Touchscreen           1
# 492      0    0                LTPS IPS LCD Touchscreen           1
# 493      0    0                     IPS LCD Touchscreen           0
#
#                                 Chipset                  Processor  \
# 0                    Exynos 2100 (5 nm)   Octa core, up to 2.9 GHz
# 1             MediaTek Helio P35 (12nm)  Octa core, up to 2.35 GHz
# 2    Qualcomm Snapdragon 778G 5G (6 nm)   Octa core, up to 2.4 GHz
# 3            Mediatek Helio G80 (12 nm)   Octa core, up to 2.0 GHz
# 4     Qualcomm Snapdragon 888 5G (5 nm)  Octa core, up to 2.84 GHz
# ..                                  ...                        ...
# 489             Mediatek MT6750 (28 nm)   Octa-core, up to 1.5 GHz
# 490     Qualcomm Snapdragon 835 (10 nm)   Octa-core, up to 2.5 GHz
# 491             Mediatek MT6737 (28 nm)         Quad-core, 1.4 GHz
# 492     Qualcomm Snapdragon 212 (28 nm)         Quad-core, 1.3 GHz
# 493            Mediatek MT6737M (28 nm)         Quad-core, 1.1 GHz
#
#                 GPU  Fingerprint FaceLock
# 0     Mali-G78 MP14            1        1
# 1    PowerVR GE8320            1        1
# 2       Adreno 642L            1        1
# 3      Mali-G52 MC2            1        1
# 4        Adreno 660            1        1
# ..              ...          ...      ...
# 489   Mali-T860 MP2            0        1
# 490      Adreno 540            1        1
# 491   Mali-T720 MP1            0        0
# 492      Adreno 304            0        0
# 493   Mali-T720 MP1            0        0
#
# [494 rows x 24 columns]

# %%
# ploting correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax =plt.subplots(3,3,figsize=(16,12))

sns.barplot(x='PriceRange',y='Camera',data=data,ax=ax[0,0])
sns.barplot(x='PriceRange',y='AvailableColors',data=data,ax=ax[0,1])
sns.barplot(x='PriceRange',y='NetworkSupport',data=data,ax=ax[0,2])
sns.barplot(x='PriceRange',y='NFC',data=data,ax=ax[1,0])
sns.barplot(x='PriceRange',y='Rom_GB',data=data,ax=ax[1,1])
sns.barplot(x='PriceRange',y='VideoRes',data=data,ax=ax[1,2])
sns.barplot(x='PriceRange',y='USB_Version',data=data,ax=ax[2,0])
sns.barplot(x='PriceRange',y='BluetoothVersion',data=data,ax=ax[2,1])
sns.barplot(x='PriceRange',y='Protection',data=data,ax=ax[2,2])

fig.savefig('plots.png', dpi=100)

# %%
# one hot encoding
data = pd.get_dummies(data, columns=['Display'])
data = pd.get_dummies(data, columns=['Chipset'])
data = pd.get_dummies(data, columns=['Processor'])
data = pd.get_dummies(data, columns=['GPU'])

# %%
# train test split

# %%
Y = data['PriceRange']
X = data.drop(['PriceRange'], axis=1)

# get all numeric columns
numeric_cols = [col for col in X.columns if X[col].dtype in ['int64', 'float64']]

# normalize numeric columns
X[numeric_cols] = data[numeric_cols].apply(lambda x: (x - x.mean()) / (x.max() - x.min()))


# test train split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

X_train
# Out:
#      ReleaseYear    Camera  AvailableColors    Ram_GB  NetworkSupport  \
# 438     0.055668 -0.008527         0.202092 -0.003712        0.257085
# 56     -0.069332 -0.008527         0.035425 -0.011540        0.007085
# 351     0.055668  0.058139        -0.131242 -0.011540        0.007085
# 222    -0.194332 -0.008527         0.035425 -0.011540        0.007085
# 362    -0.069332 -0.021027        -0.131242 -0.011540        0.007085
# ..           ...       ...              ...       ...             ...
# 106    -0.069332 -0.021027         0.035425 -0.007626        0.007085
# 270     0.055668 -0.041861        -0.131242 -0.013497        0.007085
# 348     0.180668 -0.041861         0.035425 -0.011540        0.007085
# 435     0.055668 -0.008527        -0.297908 -0.007626        0.257085
# 102    -0.069332  0.058139         0.035425 -0.007626        0.007085
#
#      BluetoothVersion    Rom_GB  BatteryCapacity  VideoRes  NumOfSensors  ...  \
# 438          0.166057  0.266339         0.053095  0.104199      0.129049  ...
# 56           0.133799  0.012371         0.003095  0.104199      0.254049  ...
# 351         -0.188782  0.266339         0.003095  0.104199      0.004049  ...
# 222         -0.124265 -0.114613         0.041428  0.104199      0.004049  ...
# 362         -0.124265 -0.114613        -0.013572  0.104199      0.254049  ...
# ..                ...       ...              ...       ...           ...  ...
# 106          0.133799 -0.114613         0.003095  0.104199      0.129049  ...
# 270         -0.188782 -0.114613         0.003095  0.104199     -0.120951  ...
# 348          0.133799  0.012371         0.169761  0.104199     -0.120951  ...
# 435          0.166057  0.266339         0.053095  0.104199      0.129049  ...
# 102          0.133799  0.012371         0.008095  0.104199      0.254049  ...
#
#      GPU_PowerVR GE8320 (650 MHz)  GPU_PowerVR GE8322  GPU_PowerVR GM9446  \
# 438                             0                   0                   0
# 56                              0                   0                   0
# 351                             0                   0                   0
# 222                             0                   0                   0
# 362                             0                   0                   0
# ..                            ...                 ...                 ...
# 106                             0                   0                   0
# 270                             0                   0                   0
# 348                             0                   0                   0
# 435                             0                   0                   0
# 102                             0                   0                   0
#
#      GPU_PowerVR GT7600 (6-core graphics)  \
# 438                                     0
# 56                                      0
# 351                                     0
# 222                                     0
# 362                                     0
# ..                                    ...
# 106                                     0
# 270                                     0
# 348                                     0
# 435                                     0
# 102                                     0
#
#      GPU_PowerVR GX6450 (quad-core graphics)  GPU_PowerVR IMG8322  \
# 438                                        0                    0
# 56                                         0                    0
# 351                                        0                    0
# 222                                        0                    0
# 362                                        0                    0
# ..                                       ...                  ...
# 106                                        0                    0
# 270                                        0                    0
# 348                                        0                    0
# 435                                        0                    0
# 102                                        0                    0
#
#      GPU_PowerVR Rogue GE8322  GPU_PowerVR Rough GE8100  \
# 438                         0                         0
# 56                          0                         0
# 351                         0                         0
# 222                         0                         0
# 362                         0                         0
# ..                        ...                       ...
# 106                         0                         0
# 270                         0                         0
# 348                         0                         0
# 435                         0                         0
# 102                         0                         0
#
#      GPU_PowerVR Series7XT Plus (6-core graphics)  GPU_Unspecified
# 438                                             0                0
# 56                                              0                0
# 351                                             0                0
# 222                                             0                0
# 362                                             0                0
# ..                                            ...              ...
# 106                                             0                0
# 270                                             0                0
# 348                                             0                0
# 435                                             0                0
# 102                                             0                0
#
# [395 rows x 378 columns]

# %% [markdown]
# ### run models

# %%
# run models

# 1. Random Forest
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, random_state=42)

model.fit(X_train, Y_train)

# predict
Y_pred = model.predict(X_test)

print("Random Forest ______________________________")
print("Accuracy: ", accuracy_score(Y_test, Y_pred))
print("Recall: ",recall_score(Y_test, Y_pred, average='macro'))
print("Precision: ",precision_score(Y_test, Y_pred, average='macro'))
print("F1 Score: ",f1_score(Y_test, Y_pred,average='macro'))
# Out:
# Random Forest ______________________________
# Accuracy:  0.8080808080808081
# Recall:  0.6851016548463357
# Precision:  0.6239283592224768
# F1 Score:  0.6491416051598223

# %%
# 2. Logistic Regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=42)

model.fit(X_train, Y_train)

# predict
Y_pred = model.predict(X_test)

print("Logistic Regression___________________________________")
print("Accuracy: ", accuracy_score(Y_test, Y_pred))
print("Recall: ",recall_score(Y_test, Y_pred, average='macro'))
print("Precision: ",precision_score(Y_test, Y_pred, average='macro'))
print("F1 Score: ",f1_score(Y_test, Y_pred,average='macro'))
# Out:
# Logistic Regression___________________________________
# Accuracy:  0.7474747474747475
# Recall:  0.6538912529550828
# Precision:  0.5748566248566249
# F1 Score:  0.6080919080919082

# %%
# 3. KNN
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=10)

model.fit(X_train, Y_train)

# Predict
Y_pred = model.predict(X_test)

print("KNN Accuracy____________________________________")
print("Accuracy: ", accuracy_score(Y_test, Y_pred))
print("Recall: ",recall_score(Y_test, Y_pred, average='macro'))
print("Precision: ",precision_score(Y_test, Y_pred, average='macro'))
print("F1 Score: ",f1_score(Y_test, Y_pred,average='macro'))
# Out:
# KNN Accuracy____________________________________
# Accuracy:  0.7777777777777778
# Recall:  0.7050354609929077
# Precision:  0.8298502758077226
# F1 Score:  0.7060244719819188

# %%
# 4. SVM
from sklearn.svm import SVC

model = SVC(random_state=42)

model.fit(X_train, Y_train)

# predict
Y_pred = model.predict(X_test)

print("SVM______________________________________")
print("Accuracy: ", accuracy_score(Y_test, Y_pred))
print("Recall: ",recall_score(Y_test, Y_pred, average='macro'))
print("Precision: ",precision_score(Y_test, Y_pred, average='macro'))
print("F1 Score: ",f1_score(Y_test, Y_pred,average='macro'))
# Out:
# SVM______________________________________
# Accuracy:  0.7878787878787878
# Recall:  0.6888794326241136
# Precision:  0.6191114599686028
# F1 Score:  0.6500952380952382
# /Users/efaz/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# 5. Naive Bayes
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

model.fit(X_train, Y_train)

# predict
Y_pred = model.predict(X_test)

print("Naive Bayes Accuracy________________________________________")
print("Accuracy: ", accuracy_score(Y_test, Y_pred))
print("Recall: ",recall_score(Y_test, Y_pred, average='macro'))
print("Precision: ",precision_score(Y_test, Y_pred, average='macro'))
print("F1 Score: ",f1_score(Y_test, Y_pred,average='macro'))
# Out:
# Naive Bayes Accuracy________________________________________
# Accuracy:  0.696969696969697
# Recall:  0.6481040189125296
# Precision:  0.5985951303598362
# F1 Score:  0.6115594035594035

# %%
# 6. Decision Tree
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

model.fit(X_train, Y_train)

# predict
Y_pred = model.predict(X_test)

print("Decision Tree Accuracy__________________________________________")
print("Accuracy: ", accuracy_score(Y_test, Y_pred))
print("Recall: ",recall_score(Y_test, Y_pred, average='macro'))
print("Precision: ",precision_score(Y_test, Y_pred, average='macro'))
print("F1 Score: ",f1_score(Y_test, Y_pred,average='macro'))
# Out:
# Decision Tree Accuracy__________________________________________
# Accuracy:  0.7474747474747475
# Recall:  0.6873475177304964
# Precision:  0.6975745816153286
# F1 Score:  0.6761751152073733

# %%
# 7. XGBoost
import xgboost as xgb

model = xgb.XGBClassifier(random_state=42,use_label_encoder=False)
model.fit(X_train, Y_train)

# predict
Y_pred = model.predict(X_test)

print("XGBoost Accuracy__________________________________________")
print("Accuracy: ", accuracy_score(Y_test, Y_pred))
print("Recall: ",recall_score(Y_test, Y_pred, average='macro'))
print("Precision: ",precision_score(Y_test, Y_pred, average='macro'))
print("F1 Score: ",f1_score(Y_test, Y_pred,average='macro'))
# Out:
# [23:08:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost Accuracy__________________________________________
# Accuracy:  0.8181818181818182
# Recall:  0.7277352245862885
# Precision:  0.7397598119707653
# F1 Score:  0.7113600815073113
